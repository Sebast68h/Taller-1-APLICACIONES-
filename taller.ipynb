# %%
def planear_viaje(vuelos:list) -> list:
    i = 0
    t = False
    while i < len(vuelos) and t == False:
        y = False:
        c = 0
        while c < len(vuelos) and y == False:
            if vuelos[i]
